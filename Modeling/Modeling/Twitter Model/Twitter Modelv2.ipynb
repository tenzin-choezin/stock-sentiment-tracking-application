# %%
#imports 
import pandas as pd
import numpy as np
import requests 
from time import sleep
from collections import Counter

# %% [markdown]
# # API Functions

# %%
headers = {"Authorization": "Bearer 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"}

# Model 1: https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment-latest

model1 = "https://api-inference.huggingface.co/models/cardiffnlp/twitter-roberta-base-sentiment-latest"

# Model 2: https://huggingface.co/mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis 

# label dict not needed, output displays score + sentiment 
model2 = "https://api-inference.huggingface.co/models/mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"

# Model 3: https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english
model3 = "https://api-inference.huggingface.co/models/distilbert-base-uncased-finetuned-sst-2-english"


def get_sentiment(string, model, type = None):
    #string - text to run through model 
    #model - model url (reference above) 
    #output types: score, label 
    done = False
    
    headers = {"Authorization": "Bearer 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"}
    while not done:
        try: 
            #access model + obtain ouput
            payload = query = {"inputs": string}
            #print(payload)
            response = requests.post(model, headers = headers, json = query) 
            print(response.json())
            output = response.json()[0]

            best = max(output, key = lambda x: x['score'])
            label = best['label'].lower()
            score = np.round(best['score'], decimals = 3)
            done = True 
        except Exception as KeyError: 
            pass
            if KeyError:
                sleep(20)  
    
    #desired output
    if type == "score": 
        return score
    if type == "label": 
        return label

    return label, score
    

vec_sentiment = np.vectorize(get_sentiment)

# %% [markdown]
# # MAIN FUNCTION

# %%
raw_data = pd.read_csv("/work/Files/Twitter Files/twitter 04-06-2022.csv")

# %%
def run_model(ticker_df):  
    
    models = [model1, model2, model3] 
    model_dict = {model1: 'model1', model2: 'model2', model3: 'model3'}
    mentions = len(ticker_df) 

    top20 = get_top20(ticker_df) 
    just20 = get_just20(ticker_df)

    ticker_df_filt = ticker_df[(ticker_df['favorite_count'] >= 2) | (ticker_df['retweet_count'] >= 1)].copy()
    
    if len(ticker_df_filt) > 150:
        data = ticker_df_filt.sample(150)

    elif len(ticker_df_filt) < 10: 
        cut = mentions //4 
        if cut < 50: 
            sample_size = min(cut, 50) 
        elif cut >= 50:
            sample_size = max(cut, 50)
        data = ticker_df.sample(sample_size)

    else:
        data = ticker_df_filt.copy()

    text = data['text'].values 
    
    for model in models: 
        label = model_dict[model] + "Sentiment" 
        result_label = model_dict[model] + "Score"  

        sentiment, score = vec_sentiment(text, model)
        data[label] = sentiment 
        data[result_label] = score 

    return mentions, data, top20, just20

# %%
#returns dictionary of dataframes for each stock ticker
def split_by_ticker(data): 
    stock_tickers = data['ticker'].unique() 

    DataFrameDict = {elem : pd.DataFrame for elem in stock_tickers}
    
    for key in DataFrameDict.keys():
        #process each dataframe 
        columns = {'full_text_preprocessed': 'text'}
        DataFrameDict[key] = data[data['ticker'] == key].copy().rename(columns = columns)
    
    return DataFrameDict

# %%
def get_top20(tweets): 
    
    data = tweets.sort_values(by = ['user.verified', 'retweet_count','favorite_count'], ascending=False).copy()
    text = data['text'].values[0:20]

    return text

# %%
def get_just20(tweets): 

    if len(tweets) > 20:
        text = tweets['text'].sample(n= 20,  replace=False).values
    
    else: 
        text = tweets['text'].values
 
    return text

# %%
def determine_majority(df): 
    data = df.copy() 
    data['Majority_Sentiment'] = [Counter([x,y,z]).most_common()[0][0] for x,y,z in zip(df['model1Sentiment'], df['model2Sentiment'], df['model3Sentiment'])]
    return data

# %%
def process_Sentiment(sentimment_Data): 
    neg_m1 = sentimment_Data[sentimment_Data['model1Sentiment'] == 'negative']['model1Score'].values 
    neg_m2 = sentimment_Data[sentimment_Data['model2Sentiment'] == 'negative']['model2Score'].values
    neg_m3 = sentimment_Data[sentimment_Data['model3Sentiment'] == 'negative']['model3Score'].values
    neg_arr = np.concatenate((neg_m1, neg_m2, neg_m3), axis = None)
    neg_avg = np.average(neg_arr)

    pos_m1 = sentimment_Data[sentimment_Data['model1Sentiment'] == 'positive']['model1Score'].values 
    pos_m2 = sentimment_Data[sentimment_Data['model2Sentiment'] == 'positive']['model2Score'].values
    pos_m3 = sentimment_Data[sentimment_Data['model3Sentiment'] == 'positive']['model3Score'].values
    pos_arr = np.concatenate((pos_m1, pos_m2, pos_m3), axis = None)
    pos_avg = np.average(pos_arr)

    total_vals = len(sentimment_Data) * 3 

    num_neg, num_pos = len(neg_arr), len(pos_arr)
    neg_weight, pos_weight = num_neg / total_vals, num_pos / total_vals
    weighted_neg, weighted_pos = neg_avg * neg_weight, pos_avg * pos_weight 

    if (num_neg / num_pos) > 0.75 and (num_neg / num_pos) < 1.25:
        sentimment_ratio = neg_avg / pos_avg
    else:
        sentimment_ratio = weighted_neg / weighted_pos

    final_sentimment = 'Negative'
    if sentimment_ratio == 1:
        final_sentimment = np.random.choice('Negative', 'Positive')
    elif sentimment_ratio < 1:
        final_sentimment = 'Positive'
    
    output_dict = {'Negative Average' : neg_avg, 'Positive Average' : pos_avg, 'Overall Sentiment' : final_sentimment}
    return output_dict

# %%
def process_Twitter(data): 
    #get data dic
    dataDic = split_by_ticker(data)
    # get tickers 


    tickers = list(dataDic.keys())
    mentions, negative_Avg, positive_Avg, overall = [], [], [], []
    top20, just20 = [],[]

    for ticker in tickers: 
        mention_count, stock, top20tweets, just20tweets = run_model(dataDic[ticker]) 
        results = process_Sentiment(stock)
        
        mentions.append(mention_count)
        negative_Avg.append(results['Negative Average'])
        positive_Avg.append(results['Positive Average'])
        overall.append(results['Overall Sentiment']) 
        top20.append(top20tweets)
        just20.append(just20tweets)

    
    output = pd.DataFrame({"Ticker": tickers,
                          "Mentions": mentions, 
                          "Negative Average": negative_Avg, 
                          "Positive Average": positive_Avg, 
                          "Overall Sentiment": overall,
                          "Top 20 Tweets": top20, 
                          "20 Quality Tweets": just20
                            })
    
    return output

# %%
output = process_Twitter(raw_data)
# Out:
# [[{'label': 'Negative', 'score': 0.7864415049552917}, {'label': 'Neutral', 'score': 0.18161430954933167}, {'label': 'Positive', 'score': 0.031944192945957184}]]
# [[{'label': 'Negative', 'score': 0.2174510806798935}, {'label': 'Neutral', 'score': 0.6718700528144836}, {'label': 'Positive', 'score': 0.11067892611026764}]]
# [[{'label': 'Negative', 'score': 0.041672900319099426}, {'label': 'Neutral', 'score': 0.8681623339653015}, {'label': 'Positive', 'score': 0.09016476571559906}]]
# [[{'label': 'Negative', 'score': 0.14725720882415771}, {'label': 'Neutral', 'score': 0.5612739324569702}, {'label': 'Positive', 'score': 0.2914688289165497}]]
# [[{'label': 'Negative', 'score': 0.024468176066875458}, {'label': 'Neutral', 'score': 0.5341298580169678}, {'label': 'Positive', 'score': 0.44140198826789856}]]
# [[{'label': 'Negative', 'score': 0.5299965739250183}, {'label': 'Neutral', 'score': 0.453073114156723}, {'label': 'Positive', 'score': 0.01693030074238777}]]
# [[{'label': 'Negative', 'score': 0.003819478675723076}, {'label': 'Neutral', 'score': 0.034544967114925385}, {'label': 'Positive', 'score': 0.9616354703903198}]]
# [[{'label': 'Negative', 'score': 0.0020708360243588686}, {'label': 'Neutral', 'score': 0.013387676328420639}, {'label': 'Positive', 'score': 0.9845415353775024}]]
# [[{'label': 'Negative', 'score': 0.054514724761247635}, {'label': 'Neutral', 'score': 0.8552872538566589}, {'label': 'Positive', 'score': 0.09019799530506134}]]
# [[{'label': 'Negative', 'score': 0.008284014649689198}, {'label': 'Neutral', 'score': 0.8808711171150208}, {'label': 'Positive', 'score': 0.11084494739770889}]]
# [[{'label': 'Negative', 'score': 0.026484142988920212}, {'label': 'Neutral', 'score': 0.9278188943862915}, {'label': 'Positive', 'score': 0.045696962624788284}]]
# [[{'label': 'Negative', 'score': 0.03955164551734924}, {'label': 'Neutral', 'score': 0.6045420169830322}, {'label': 'Positive', 'score': 0.35590627789497375}]]
# [[{'label': 'Negative', 'score': 0.016760436818003654}, {'label': 'Neutral', 'score': 0.27282091975212097}, {'label': 'Positive', 'score': 0.7104186415672302}]]
# [[{'label': 'Negative', 'score': 0.0396176278591156}, {'label': 'Neutral', 'score': 0.8795757293701172}, {'label': 'Positive', 'score': 0.08080653101205826}]]
# [[{'label': 'Negative', 'score': 0.017828600481152534}, {'label': 'Neutral', 'score': 0.7851378917694092}, {'label': 'Positive', 'score': 0.1970335692167282}]]
# [[{'label': 'Negative', 'score': 0.017828600481152534}, {'label': 'Neutral', 'score': 0.7851378917694092}, {'label': 'Positive', 'score': 0.1970335692167282}]]
# [[{'label': 'Negative', 'score': 0.7224341034889221}, {'label': 'Neutral', 'score': 0.24852612614631653}, {'label': 'Positive', 'score': 0.029039764776825905}]]
# [[{'label': 'Negative', 'score': 0.028455784544348717}, {'label': 'Neutral', 'score': 0.9359747171401978}, {'label': 'Positive', 'score': 0.03556952625513077}]]
# [[{'label': 'Negative', 'score': 0.061588387936353683}, {'label': 'Neutral', 'score': 0.5040996670722961}, {'label': 'Positive', 'score': 0.4343119263648987}]]
# [[{'label': 'Negative', 'score': 0.19861508905887604}, {'label': 'Neutral', 'score': 0.6699317693710327}, {'label': 'Positive', 'score': 0.13145320117473602}]]
# [[{'label': 'Negative', 'score': 0.27563706040382385}, {'label': 'Neutral', 'score': 0.6704899668693542}, {'label': 'Positive', 'score': 0.05387294292449951}]]
# [[{'label': 'Negative', 'score': 0.13955175876617432}, {'label': 'Neutral', 'score': 0.7035810947418213}, {'label': 'Positive', 'score': 0.1568671315908432}]]
# [[{'label': 'Negative', 'score': 0.05900735780596733}, {'label': 'Neutral', 'score': 0.8363509774208069}, {'label': 'Positive', 'score': 0.10464170575141907}]]
# [[{'label': 'Negative', 'score': 0.05651041865348816}, {'label': 'Neutral', 'score': 0.9139958024024963}, {'label': 'Positive', 'score': 0.029493698850274086}]]
# [[{'label': 'Negative', 'score': 0.008783130906522274}, {'label': 'Neutral', 'score': 0.1660047173500061}, {'label': 'Positive', 'score': 0.8252121210098267}]]
# [[{'label': 'Negative', 'score': 0.8360558152198792}, {'label': 'Neutral', 'score': 0.15502610802650452}, {'label': 'Positive', 'score': 0.008918055333197117}]]
# [[{'label': 'Negative', 'score': 0.23013058304786682}, {'label': 'Neutral', 'score': 0.6164907217025757}, {'label': 'Positive', 'score': 0.15337875485420227}]]
# [[{'label': 'Negative', 'score': 0.02011541835963726}, {'label': 'Neutral', 'score': 0.7122260332107544}, {'label': 'Positive', 'score': 0.2676585614681244}]]
# [[{'label': 'Negative', 'score': 0.7163119912147522}, {'label': 'Neutral', 'score': 0.2663430869579315}, {'label': 'Positive', 'score': 0.017344964668154716}]]
# [[{'label': 'Negative', 'score': 0.8425966501235962}, {'label': 'Neutral', 'score': 0.1461915522813797}, {'label': 'Positive', 'score': 0.011211843229830265}]]
# [[{'label': 'Negative', 'score': 0.32307255268096924}, {'label': 'Neutral', 'score': 0.5830332040786743}, {'label': 'Positive', 'score': 0.09389419108629227}]]
# [[{'label': 'Negative', 'score': 0.754192590713501}, {'label': 'Neutral', 'score': 0.23399916291236877}, {'label': 'Positive', 'score': 0.011808299459517002}]]
# [[{'label': 'Negative', 'score': 0.7047089338302612}, {'label': 'Neutral', 'score': 0.2832343578338623}, {'label': 'Positive', 'score': 0.012056729756295681}]]
# [[{'label': 'Negative', 'score': 0.24564804136753082}, {'label': 'Neutral', 'score': 0.7268263101577759}, {'label': 'Positive', 'score': 0.0275256484746933}]]
# [[{'label': 'Negative', 'score': 0.01965314894914627}, {'label': 'Neutral', 'score': 0.749910831451416}, {'label': 'Positive', 'score': 0.2304360419511795}]]
# [[{'label': 'Negative', 'score': 0.045262645930051804}, {'label': 'Neutral', 'score': 0.7545706033706665}, {'label': 'Positive', 'score': 0.20016668736934662}]]
# [[{'label': 'Negative', 'score': 0.06817317008972168}, {'label': 'Neutral', 'score': 0.7465999126434326}, {'label': 'Positive', 'score': 0.1852269172668457}]]
# [[{'label': 'Negative', 'score': 0.3007444441318512}, {'label': 'Neutral', 'score': 0.4233334958553314}, {'label': 'Positive', 'score': 0.2759220600128174}]]
# [[{'label': 'Negative', 'score': 0.13020841777324677}, {'label': 'Neutral', 'score': 0.4558015465736389}, {'label': 'Positive', 'score': 0.4139901101589203}]]
# [[{'label': 'Negative', 'score': 0.016219772398471832}, {'label': 'Neutral', 'score': 0.5436565279960632}, {'label': 'Positive', 'score': 0.44012370705604553}]]
# [[{'label': 'Negative', 'score': 0.03485961630940437}, {'label': 'Neutral', 'score': 0.8497849702835083}, {'label': 'Positive', 'score': 0.11535536497831345}]]
# [[{'label': 'negative', 'score': 0.0026602859143167734}, {'label': 'neutral', 'score': 0.9972735047340393}, {'label': 'positive', 'score': 6.616420432692394e-05}]]
# [[{'label': 'negative', 'score': 0.0026602859143167734}, {'label': 'neutral', 'score': 0.9972735047340393}, {'label': 'positive', 'score': 6.616420432692394e-05}]]
# [[{'label': 'negative', 'score': 0.0006123853381723166}, {'label': 'neutral', 'score': 0.00043356820242479444}, {'label': 'positive', 'score': 0.9989540576934814}]]
# [[{'label': 'negative', 'score': 0.0006123853381723166}, {'label': 'neutral', 'score': 0.00043356820242479444}, {'label': 'positive', 'score': 0.9989540576934814}]]
# [[{'label': 'negative', 'score': 9.918394061969593e-05}, {'label': 'neutral', 'score': 0.9990344047546387}, {'label': 'positive', 'score': 0.0008664608467370272}]]
# [[{'label': 'negative', 'score': 7.077667396515608e-05}, {'label': 'neutral', 'score': 0.999850869178772}, {'label': 'positive', 'score': 7.83430878072977e-05}]]
# [[{'label': 'negative', 'score': 0.12753187119960785}, {'label': 'neutral', 'score': 0.8720044493675232}, {'label': 'positive', 'score': 0.0004636450030375272}]]
# [[{'label': 'negative', 'score': 0.0003338112437631935}, {'label': 'neutral', 'score': 0.9952946305274963}, {'label': 'positive', 'score': 0.0043715666979551315}]]
# [[{'label': 'negative', 'score': 0.0003829298948403448}, {'label': 'neutral', 'score': 0.003526729764416814}, {'label': 'positive', 'score': 0.9960903525352478}]]
# [[{'label': 'negative', 'score': 7.338356226682663e-05}, {'label': 'neutral', 'score': 0.9998769760131836}, {'label': 'positive', 'score': 4.9608170229475945e-05}]]
# [[{'label': 'negative', 'score': 0.000480059563415125}, {'label': 'neutral', 'score': 0.007069857325404882}, {'label': 'positive', 'score': 0.9924501180648804}]]
# [[{'label': 'negative', 'score': 0.96235191822052}, {'label': 'neutral', 'score': 0.03660864010453224}, {'label': 'positive', 'score': 0.001039498602040112}]]
# [[{'label': 'negative', 'score': 0.00030312701710499823}, {'label': 'neutral', 'score': 0.0005617037531919777}, {'label': 'positive', 'score': 0.9991351962089539}]]
# [[{'label': 'negative', 'score': 0.00027949362993240356}, {'label': 'neutral', 'score': 0.9884734749794006}, {'label': 'positive', 'score': 0.01124698854982853}]]
# [[{'label': 'negative', 'score': 6.910145020810887e-05}, {'label': 'neutral', 'score': 0.9997809529304504}, {'label': 'positive', 'score': 0.00014997470134403557}]]
# [[{'label': 'negative', 'score': 0.25102269649505615}, {'label': 'neutral', 'score': 0.7428827285766602}, {'label': 'positive', 'score': 0.006094601005315781}]]
# [[{'label': 'negative', 'score': 0.00042264294461347163}, {'label': 'neutral', 'score': 0.0028191518504172564}, {'label': 'positive', 'score': 0.9967581629753113}]]
# [[{'label': 'negative', 'score': 9.85015940386802e-05}, {'label': 'neutral', 'score': 0.9998401403427124}, {'label': 'positive', 'score': 6.135118019301444e-05}]]
# [[{'label': 'negative', 'score': 0.0011995364911854267}, {'label': 'neutral', 'score': 0.03747525066137314}, {'label': 'positive', 'score': 0.9613251686096191}]]
# [[{'label': 'negative', 'score': 0.013733675703406334}, {'label': 'neutral', 'score': 0.863696277141571}, {'label': 'positive', 'score': 0.1225699633359909}]]
# [[{'label': 'negative', 'score': 0.0002455174399074167}, {'label': 'neutral', 'score': 0.9996325969696045}, {'label': 'positive', 'score': 0.00012194665032438934}]]
# [[{'label': 'negative', 'score': 0.00017965605366043746}, {'label': 'neutral', 'score': 0.9930847883224487}, {'label': 'positive', 'score': 0.006735468283295631}]]
# [[{'label': 'negative', 'score': 7.443375943694264e-05}, {'label': 'neutral', 'score': 0.9998350143432617}, {'label': 'positive', 'score': 9.064131154445931e-05}]]
# [[{'label': 'negative', 'score': 0.0004970197915099561}, {'label': 'neutral', 'score': 0.9988582134246826}, {'label': 'positive', 'score': 0.0006448365747928619}]]
# [[{'label': 'negative', 'score': 9.638939809519798e-05}, {'label': 'neutral', 'score': 0.9998216032981873}, {'label': 'positive', 'score': 8.204956975532696e-05}]]
# [[{'label': 'negative', 'score': 9.239790233550593e-05}, {'label': 'neutral', 'score': 0.999823272228241}, {'label': 'positive', 'score': 8.433764014625922e-05}]]
# [[{'label': 'negative', 'score': 7.474606536561623e-05}, {'label': 'neutral', 'score': 0.9998611211776733}, {'label': 'positive', 'score': 6.413577648345381e-05}]]
# [[{'label': 'negative', 'score': 7.885937520768493e-05}, {'label': 'neutral', 'score': 0.9998351335525513}, {'label': 'positive', 'score': 8.58915809658356e-05}]]
# [[{'label': 'negative', 'score': 0.0012220328208059072}, {'label': 'neutral', 'score': 0.9986000657081604}, {'label': 'positive', 'score': 0.00017780723283067346}]]
# [[{'label': 'negative', 'score': 0.06892332434654236}, {'label': 'neutral', 'score': 0.0035045836120843887}, {'label': 'positive', 'score': 0.9275721311569214}]]
# [[{'label': 'negative', 'score': 0.01906757242977619}, {'label': 'neutral', 'score': 0.0009987965459004045}, {'label': 'positive', 'score': 0.9799336194992065}]]
# [[{'label': 'negative', 'score': 8.655434794491157e-05}, {'label': 'neutral', 'score': 0.9994358420372009}, {'label': 'positive', 'score': 0.00047758684377186}]]
# [[{'label': 'negative', 'score': 0.00016887186211533844}, {'label': 'neutral', 'score': 0.9991044402122498}, {'label': 'positive', 'score': 0.0007266479660756886}]]
# [[{'label': 'negative', 'score': 0.9721614122390747}, {'label': 'neutral', 'score': 0.021162496879696846}, {'label': 'positive', 'score': 0.006676137447357178}]]
# [[{'label': 'negative', 'score': 0.998401939868927}, {'label': 'neutral', 'score': 0.00036033877404406667}, {'label': 'positive', 'score': 0.0012376385275274515}]]
# [[{'label': 'negative', 'score': 9.328944724984467e-05}, {'label': 'neutral', 'score': 0.9994210004806519}, {'label': 'positive', 'score': 0.00048570509534329176}]]
# [[{'label': 'negative', 'score': 0.0004261384892743081}, {'label': 'neutral', 'score': 0.9803671836853027}, {'label': 'positive', 'score': 0.019206665456295013}]]
# [[{'label': 'negative', 'score': 7.008295506238937e-05}, {'label': 'neutral', 'score': 0.999848484992981}, {'label': 'positive', 'score': 8.144555613398552e-05}]]
# [[{'label': 'negative', 'score': 7.497599290218204e-05}, {'label': 'neutral', 'score': 0.9996500015258789}, {'label': 'positive', 'score': 0.0002750593703240156}]]
# [[{'label': 'negative', 'score': 7.076022302499041e-05}, {'label': 'neutral', 'score': 0.9998539686203003}, {'label': 'positive', 'score': 7.524324610130861e-05}]]
# [[{'label': 'negative', 'score': 0.05643852800130844}, {'label': 'neutral', 'score': 0.007682332769036293}, {'label': 'positive', 'score': 0.9358791708946228}]]
# [[{'label': 'negative', 'score': 0.0002895045618060976}, {'label': 'neutral', 'score': 0.0003431305813137442}, {'label': 'positive', 'score': 0.9993674159049988}]]
# [[{'label': 'negative', 'score': 0.00040373890078626573}, {'label': 'neutral', 'score': 0.8928977251052856}, {'label': 'positive', 'score': 0.10669849067926407}]]
# [[{'label': 'negative', 'score': 6.53310416964814e-05}, {'label': 'neutral', 'score': 0.999864935874939}, {'label': 'positive', 'score': 6.97372670401819e-05}]]
# [[{'label': 'negative', 'score': 6.53310416964814e-05}, {'label': 'neutral', 'score': 0.999864935874939}, {'label': 'positive', 'score': 6.97372670401819e-05}]]
# [[{'label': 'negative', 'score': 9.118899470195174e-05}, {'label': 'neutral', 'score': 0.9998233914375305}, {'label': 'positive', 'score': 8.546755998395383e-05}]]
# [[{'label': 'negative', 'score': 6.522335752379149e-05}, {'label': 'neutral', 'score': 0.9995753169059753}, {'label': 'positive', 'score': 0.00035951638710685074}]]
# [[{'label': 'negative', 'score': 6.529406527988613e-05}, {'label': 'neutral', 'score': 0.9998575448989868}, {'label': 'positive', 'score': 7.711892976658419e-05}]]
# [[{'label': 'negative', 'score': 0.0003210747381672263}, {'label': 'neutral', 'score': 0.999427855014801}, {'label': 'positive', 'score': 0.00025105971144512296}]]
# [[{'label': 'negative', 'score': 8.728934335522354e-05}, {'label': 'neutral', 'score': 0.9998559951782227}, {'label': 'positive', 'score': 5.679208697983995e-05}]]
# [[{'label': 'negative', 'score': 0.9963791966438293}, {'label': 'neutral', 'score': 0.0027232386637479067}, {'label': 'positive', 'score': 0.0008976258686743677}]]
# [[{'label': 'negative', 'score': 0.000195259737665765}, {'label': 'neutral', 'score': 0.0003560350160114467}, {'label': 'positive', 'score': 0.9994487166404724}]]
# [[{'label': 'negative', 'score': 6.756915536243469e-05}, {'label': 'neutral', 'score': 0.9998681545257568}, {'label': 'positive', 'score': 6.426461914088577e-05}]]
# [[{'label': 'negative', 'score': 0.0005733614088967443}, {'label': 'neutral', 'score': 0.20132125914096832}, {'label': 'positive', 'score': 0.7981053590774536}]]
# [[{'label': 'negative', 'score': 0.9984251260757446}, {'label': 'neutral', 'score': 0.0010126687120646238}, {'label': 'positive', 'score': 0.0005622100434266031}]]
# [[{'label': 'negative', 'score': 0.0006688726134598255}, {'label': 'neutral', 'score': 0.0012294838670641184}, {'label': 'positive', 'score': 0.9981016516685486}]]
# [[{'label': 'negative', 'score': 7.7690405305475e-05}, {'label': 'neutral', 'score': 0.9998468160629272}, {'label': 'positive', 'score': 7.54071370465681e-05}]]
# [[{'label': 'negative', 'score': 0.9961004257202148}, {'label': 'neutral', 'score': 0.0006960389437153935}, {'label': 'positive', 'score': 0.0032034653704613447}]]
# [[{'label': 'negative', 'score': 0.9934560656547546}, {'label': 'neutral', 'score': 0.006058204919099808}, {'label': 'positive', 'score': 0.0004856676096096635}]]
# [[{'label': 'negative', 'score': 6.861578003736213e-05}, {'label': 'neutral', 'score': 0.9998517036437988}, {'label': 'positive', 'score': 7.963654934428632e-05}]]
# [[{'label': 'negative', 'score': 0.9984475374221802}, {'label': 'neutral', 'score': 0.0004087427514605224}, {'label': 'positive', 'score': 0.00114369613584131}]]
# [[{'label': 'negative', 'score': 0.9984210729598999}, {'label': 'neutral', 'score': 0.0003880813019350171}, {'label': 'positive', 'score': 0.0011907819425687194}]]
# [[{'label': 'negative', 'score': 0.010241609066724777}, {'label': 'neutral', 'score': 0.0022557994816452265}, {'label': 'positive', 'score': 0.9875025749206543}]]
# [[{'label': 'negative', 'score': 0.000845574657432735}, {'label': 'neutral', 'score': 0.6228978633880615}, {'label': 'positive', 'score': 0.3762565851211548}]]
# [[{'label': 'negative', 'score': 0.0011161976726725698}, {'label': 'neutral', 'score': 0.9759870767593384}, {'label': 'positive', 'score': 0.022896673530340195}]]
# [[{'label': 'negative', 'score': 0.00010369432857260108}, {'label': 'neutral', 'score': 0.9998021721839905}, {'label': 'positive', 'score': 9.412337385583669e-05}]]
# [[{'label': 'negative', 'score': 0.00012308558507356793}, {'label': 'neutral', 'score': 0.9997735619544983}, {'label': 'positive', 'score': 0.0001033524313243106}]]
# [[{'label': 'negative', 'score': 7.8544020652771e-05}, {'label': 'neutral', 'score': 0.9997965693473816}, {'label': 'positive', 'score': 0.0001248692424269393}]]
# [[{'label': 'negative', 'score': 8.902587433112785e-05}, {'label': 'neutral', 'score': 0.9998286962509155}, {'label': 'positive', 'score': 8.222914766520262e-05}]]
# [[{'label': 'negative', 'score': 0.05879382789134979}, {'label': 'neutral', 'score': 0.48006874322891235}, {'label': 'positive', 'score': 0.4611373245716095}]]
# [[{'label': 'NEGATIVE', 'score': 0.99455726146698}, {'label': 'POSITIVE', 'score': 0.005442758556455374}]]
# [[{'label': 'NEGATIVE', 'score': 0.99455726146698}, {'label': 'POSITIVE', 'score': 0.005442758556455374}]]
# [[{'label': 'NEGATIVE', 'score': 0.9764619469642639}, {'label': 'POSITIVE', 'score': 0.023538079112768173}]]
# [[{'label': 'NEGATIVE', 'score': 0.9764619469642639}, {'label': 'POSITIVE', 'score': 0.023538079112768173}]]
# [[{'label': 'NEGATIVE', 'score': 0.0030295480974018574}, {'label': 'POSITIVE', 'score': 0.9969704151153564}]]
# [[{'label': 'NEGATIVE', 'score': 0.010793447494506836}, {'label': 'POSITIVE', 'score': 0.9892065525054932}]]
# [[{'label': 'NEGATIVE', 'score': 0.991856575012207}, {'label': 'POSITIVE', 'score': 0.008143412880599499}]]
# [[{'label': 'NEGATIVE', 'score': 0.0009274017065763474}, {'label': 'POSITIVE', 'score': 0.9990725517272949}]]
# [[{'label': 'NEGATIVE', 'score': 0.0028910867404192686}, {'label': 'POSITIVE', 'score': 0.9971088767051697}]]
# [[{'label': 'NEGATIVE', 'score': 0.9777297973632812}, {'label': 'POSITIVE', 'score': 0.02227017842233181}]]
# [[{'label': 'NEGATIVE', 'score': 0.9537447094917297}, {'label': 'POSITIVE', 'score': 0.04625530540943146}]]
# [[{'label': 'NEGATIVE', 'score': 0.9997186064720154}, {'label': 'POSITIVE', 'score': 0.0002813776663970202}]]
# [[{'label': 'NEGATIVE', 'score': 0.9764428734779358}, {'label': 'POSITIVE', 'score': 0.02355714701116085}]]
# [[{'label': 'NEGATIVE', 'score': 0.1123233214020729}, {'label': 'POSITIVE', 'score': 0.8876765966415405}]]
# [[{'label': 'NEGATIVE', 'score': 0.004816687200218439}, {'label': 'POSITIVE', 'score': 0.9951832890510559}]]
# [[{'label': 'NEGATIVE', 'score': 0.9995167255401611}, {'label': 'POSITIVE', 'score': 0.0004832666600123048}]]
# [[{'label': 'NEGATIVE', 'score': 0.0020926811266690493}, {'label': 'POSITIVE', 'score': 0.9979074001312256}]]
# [[{'label': 'NEGATIVE', 'score': 0.6225113272666931}, {'label': 'POSITIVE', 'score': 0.3774887025356293}]]
# [[{'label': 'NEGATIVE', 'score': 0.990211009979248}, {'label': 'POSITIVE', 'score': 0.009789046831429005}]]
# [[{'label': 'NEGATIVE', 'score': 0.9994094371795654}, {'label': 'POSITIVE', 'score': 0.0005905232392251492}]]
# [[{'label': 'NEGATIVE', 'score': 0.0007114732870832086}, {'label': 'POSITIVE', 'score': 0.9992884397506714}]]
# [[{'label': 'NEGATIVE', 'score': 0.9839364290237427}, {'label': 'POSITIVE', 'score': 0.0160636305809021}]]
# [[{'label': 'NEGATIVE', 'score': 0.9871726036071777}, {'label': 'POSITIVE', 'score': 0.012827347032725811}]]
# [[{'label': 'NEGATIVE', 'score': 0.7985317707061768}, {'label': 'POSITIVE', 'score': 0.20146824419498444}]]
# [[{'label': 'NEGATIVE', 'score': 0.9857071042060852}, {'label': 'POSITIVE', 'score': 0.014292859472334385}]]
# [[{'label': 'NEGATIVE', 'score': 0.9728676676750183}, {'label': 'POSITIVE', 'score': 0.027132291346788406}]]
# [[{'label': 'NEGATIVE', 'score': 0.9031546711921692}, {'label': 'POSITIVE', 'score': 0.09684532880783081}]]
# [[{'label': 'NEGATIVE', 'score': 0.9809649586677551}, {'label': 'POSITIVE', 'score': 0.0190350990742445}]]
# [[{'label': 'NEGATIVE', 'score': 0.27574655413627625}, {'label': 'POSITIVE', 'score': 0.7242534160614014}]]
# [[{'label': 'NEGATIVE', 'score': 0.9989905953407288}, {'label': 'POSITIVE', 'score': 0.0010093791643157601}]]
# [[{'label': 'NEGATIVE', 'score': 0.7626851797103882}, {'label': 'POSITIVE', 'score': 0.23731482028961182}]]
# [[{'label': 'NEGATIVE', 'score': 0.9959973096847534}, {'label': 'POSITIVE', 'score': 0.004002686124294996}]]
# [[{'label': 'NEGATIVE', 'score': 0.9971588850021362}, {'label': 'POSITIVE', 'score': 0.0028411136008799076}]]
# [[{'label': 'NEGATIVE', 'score': 0.9912596344947815}, {'label': 'POSITIVE', 'score': 0.008740362711250782}]]
# [[{'label': 'NEGATIVE', 'score': 0.9916741251945496}, {'label': 'POSITIVE', 'score': 0.008325891569256783}]]
# [[{'label': 'NEGATIVE', 'score': 0.9990217685699463}, {'label': 'POSITIVE', 'score': 0.0009782335255295038}]]
# [[{'label': 'NEGATIVE', 'score': 0.00012789411994162947}, {'label': 'POSITIVE', 'score': 0.999872088432312}]]
# [[{'label': 'NEGATIVE', 'score': 0.9974167346954346}, {'label': 'POSITIVE', 'score': 0.0025832548271864653}]]
# [[{'label': 'NEGATIVE', 'score': 0.9850035309791565}, {'label': 'POSITIVE', 'score': 0.014996543526649475}]]
# [[{'label': 'NEGATIVE', 'score': 0.9979581832885742}, {'label': 'POSITIVE', 'score': 0.002041788073256612}]]
# [[{'label': 'NEGATIVE', 'score': 0.0475444570183754}, {'label': 'POSITIVE', 'score': 0.9524555206298828}]]
# [[{'label': 'NEGATIVE', 'score': 0.9944367408752441}, {'label': 'POSITIVE', 'score': 0.00556325213983655}]]
# [[{'label': 'NEGATIVE', 'score': 0.9983744621276855}, {'label': 'POSITIVE', 'score': 0.001625486183911562}]]
# [[{'label': 'NEGATIVE', 'score': 0.9923548698425293}, {'label': 'POSITIVE', 'score': 0.007645103614777327}]]
# [[{'label': 'NEGATIVE', 'score': 0.9923548698425293}, {'label': 'POSITIVE', 'score': 0.007645103614777327}]]
# [[{'label': 'NEGATIVE', 'score': 0.9956092238426208}, {'label': 'POSITIVE', 'score': 0.004390726797282696}]]
# [[{'label': 'NEGATIVE', 'score': 0.5601220726966858}, {'label': 'POSITIVE', 'score': 0.43987786769866943}]]
# [[{'label': 'NEGATIVE', 'score': 0.9433958530426025}, {'label': 'POSITIVE', 'score': 0.05660418048501015}]]
# [[{'label': 'NEGATIVE', 'score': 0.986221194267273}, {'label': 'POSITIVE', 'score': 0.013778804801404476}]]
# [[{'label': 'NEGATIVE', 'score': 0.7990602254867554}, {'label': 'POSITIVE', 'score': 0.20093970000743866}]]
# [[{'label': 'NEGATIVE', 'score': 0.9937697052955627}, {'label': 'POSITIVE', 'score': 0.006230323109775782}]]
# [[{'label': 'NEGATIVE', 'score': 0.4332982301712036}, {'label': 'POSITIVE', 'score': 0.5667017102241516}]]
# [[{'label': 'NEGATIVE', 'score': 0.9955371618270874}, {'label': 'POSITIVE', 'score': 0.004462872166186571}]]
# [[{'label': 'NEGATIVE', 'score': 0.9150598645210266}, {'label': 'POSITIVE', 'score': 0.08494013547897339}]]
# [[{'label': 'NEGATIVE', 'score': 0.9997233748435974}, {'label': 'POSITIVE', 'score': 0.0002766119141597301}]]
# [[{'label': 'NEGATIVE', 'score': 0.9936057329177856}, {'label': 'POSITIVE', 'score': 0.006394253112375736}]]
# [[{'label': 'NEGATIVE', 'score': 0.0003734356723725796}, {'label': 'POSITIVE', 'score': 0.9996265172958374}]]
# [[{'label': 'NEGATIVE', 'score': 0.9979422688484192}, {'label': 'POSITIVE', 'score': 0.0020576869137585163}]]
# [[{'label': 'NEGATIVE', 'score': 0.9976792931556702}, {'label': 'POSITIVE', 'score': 0.002320754574611783}]]
# [[{'label': 'NEGATIVE', 'score': 0.9798343777656555}, {'label': 'POSITIVE', 'score': 0.020165642723441124}]]
# [[{'label': 'NEGATIVE', 'score': 0.9994410872459412}, {'label': 'POSITIVE', 'score': 0.0005588721251115203}]]
# [[{'label': 'NEGATIVE', 'score': 0.9993871450424194}, {'label': 'POSITIVE', 'score': 0.0006128366803750396}]]
# [[{'label': 'NEGATIVE', 'score': 0.9972570538520813}, {'label': 'POSITIVE', 'score': 0.0027430139016360044}]]
# [[{'label': 'NEGATIVE', 'score': 0.9397173523902893}, {'label': 'POSITIVE', 'score': 0.060282573103904724}]]
# [[{'label': 'NEGATIVE', 'score': 0.004942010156810284}, {'label': 'POSITIVE', 'score': 0.9950580596923828}]]
# [[{'label': 'NEGATIVE', 'score': 0.0014280619798228145}, {'label': 'POSITIVE', 'score': 0.9985718727111816}]]
# [[{'label': 'NEGATIVE', 'score': 0.053557462990283966}, {'label': 'POSITIVE', 'score': 0.9464425444602966}]]
# [[{'label': 'NEGATIVE', 'score': 0.0006045281770639122}, {'label': 'POSITIVE', 'score': 0.999395489692688}]]
# [[{'label': 'NEGATIVE', 'score': 0.008680084720253944}, {'label': 'POSITIVE', 'score': 0.9913199543952942}]]
# [[{'label': 'NEGATIVE', 'score': 0.9986575841903687}, {'label': 'POSITIVE', 'score': 0.0013423757627606392}]]
# [[{'label': 'Negative', 'score': 0.027546698227524757}, {'label': 'Neutral', 'score': 0.8795819282531738}, {'label': 'Positive', 'score': 0.09287138283252716}]]
# [[{'label': 'Negative', 'score': 0.027546698227524757}, {'label': 'Neutral', 'score': 0.8795819282531738}, {'label': 'Positive', 'score': 0.09287138283252716}]]
# [[{'label': 'Negative', 'score': 0.8856024742126465}, {'label': 'Neutral', 'score': 0.10793780535459518}, {'label': 'Positive', 'score': 0.006459703668951988}]]
# [[{'label': 'Negative', 'score': 0.029611824080348015}, {'label': 'Neutral', 'score': 0.8509839773178101}, {'label': 'Positive', 'score': 0.1194041296839714}]]
# [[{'label': 'Negative', 'score': 0.021581245586276054}, {'label': 'Neutral', 'score': 0.9178473353385925}, {'label': 'Positive', 'score': 0.06057148426771164}]]
# [[{'label': 'Negative', 'score': 0.007581895217299461}, {'label': 'Neutral', 'score': 0.850052535533905}, {'label': 'Positive', 'score': 0.14236558973789215}]]
# [[{'label': 'Negative', 'score': 0.025616979226469994}, {'label': 'Neutral', 'score': 0.7151685357093811}, {'label': 'Positive', 'score': 0.25921449065208435}]]
# [[{'label': 'Negative', 'score': 0.05285217612981796}, {'label': 'Neutral', 'score': 0.8187650442123413}, {'label': 'Positive', 'score': 0.12838280200958252}]]
# [[{'label': 'Negative', 'score': 0.8044461011886597}, {'label': 'Neutral', 'score': 0.177552729845047}, {'label': 'Positive', 'score': 0.018001167103648186}]]
# [[{'label': 'Negative', 'score': 0.013552878983318806}, {'label': 'Neutral', 'score': 0.8989099860191345}, {'label': 'Positive', 'score': 0.08753713965415955}]]
# [[{'label': 'Negative', 'score': 0.017237327992916107}, {'label': 'Neutral', 'score': 0.9389176964759827}, {'label': 'Positive', 'score': 0.043845050036907196}]]
# [[{'label': 'Negative', 'score': 0.06642430275678635}, {'label': 'Neutral', 'score': 0.713595449924469}, {'label': 'Positive', 'score': 0.21998022496700287}]]
# [[{'label': 'Negative', 'score': 0.012077306397259235}, {'label': 'Neutral', 'score': 0.37966594099998474}, {'label': 'Positive', 'score': 0.6082566976547241}]]
# [[{'label': 'Negative', 'score': 0.1531827449798584}, {'label': 'Neutral', 'score': 0.7962458729743958}, {'label': 'Positive', 'score': 0.05057137832045555}]]
# [[{'label': 'Negative', 'score': 0.04114807769656181}, {'label': 'Neutral', 'score': 0.8613601922988892}, {'label': 'Positive', 'score': 0.09749162942171097}]]
# [[{'label': 'Negative', 'score': 0.020990602672100067}, {'label': 'Neutral', 'score': 0.8273897171020508}, {'label': 'Positive', 'score': 0.15161973237991333}]]
# [[{'label': 'Negative', 'score': 0.6160926818847656}, {'label': 'Neutral', 'score': 0.3618307411670685}, {'label': 'Positive', 'score': 0.022076627239584923}]]
# [[{'label': 'Negative', 'score': 0.009082112461328506}, {'label': 'Neutral', 'score': 0.11044353246688843}, {'label': 'Positive', 'score': 0.880474328994751}]]
# [[{'label': 'Negative', 'score': 0.5015622973442078}, {'label': 'Neutral', 'score': 0.4693824350833893}, {'label': 'Positive', 'score': 0.029055243358016014}]]
# [[{'label': 'Negative', 'score': 0.16279982030391693}, {'label': 'Neutral', 'score': 0.7684134840965271}, {'label': 'Positive', 'score': 0.06878671795129776}]]
# [[{'label': 'Negative', 'score': 0.11106378585100174}, {'label': 'Neutral', 'score': 0.8693016767501831}, {'label': 'Positive', 'score': 0.01963457465171814}]]
# [[{'label': 'Negative', 'score': 0.007667113561183214}, {'label': 'Neutral', 'score': 0.8113662004470825}, {'label': 'Positive', 'score': 0.18096673488616943}]]
# [[{'label': 'Negative', 'score': 0.06913162022829056}, {'label': 'Neutral', 'score': 0.7589007616043091}, {'label': 'Positive', 'score': 0.17196765542030334}]]
# [[{'label': 'Negative', 'score': 0.101859912276268}, {'label': 'Neutral', 'score': 0.8776775002479553}, {'label': 'Positive', 'score': 0.02046262100338936}]]
# [[{'label': 'Negative', 'score': 0.9186514616012573}, {'label': 'Neutral', 'score': 0.0737680047750473}, {'label': 'Positive', 'score': 0.0075805336236953735}]]
# [[{'label': 'Negative', 'score': 0.25646740198135376}, {'label': 'Neutral', 'score': 0.7162721753120422}, {'label': 'Positive', 'score': 0.027260389178991318}]]
# [[{'label': 'Negative', 'score': 0.00284629431553185}, {'label': 'Neutral', 'score': 0.016558196395635605}, {'label': 'Positive', 'score': 0.9805954694747925}]]
# [[{'label': 'Negative', 'score': 0.9007691144943237}, {'label': 'Neutral', 'score': 0.09340356290340424}, {'label': 'Positive', 'score': 0.005827353335916996}]]
# [[{'label': 'Negative', 'score': 0.4505792260169983}, {'label': 'Neutral', 'score': 0.5228223204612732}, {'label': 'Positive', 'score': 0.02659844420850277}]]
# [[{'label': 'Negative', 'score': 0.002762122778221965}, {'label': 'Neutral', 'score': 0.16970066726207733}, {'label': 'Positive', 'score': 0.8275371789932251}]]
# [[{'label': 'Negative', 'score': 0.015315823256969452}, {'label': 'Neutral', 'score': 0.9224127531051636}, {'label': 'Positive', 'score': 0.062271445989608765}]]
# [[{'label': 'Negative', 'score': 0.012430236674845219}, {'label': 'Neutral', 'score': 0.9456192255020142}, {'label': 'Positive', 'score': 0.04195051267743111}]]
# [[{'label': 'Negative', 'score': 0.07010290771722794}, {'label': 'Neutral', 'score': 0.24370437860488892}, {'label': 'Positive', 'score': 0.6861927509307861}]]
# [[{'label': 'Negative', 'score': 0.014651874080300331}, {'label': 'Neutral', 'score': 0.8533250689506531}, {'label': 'Positive', 'score': 0.13202308118343353}]]
# [[{'label': 'Negative', 'score': 0.2975882291793823}, {'label': 'Neutral', 'score': 0.6582204699516296}, {'label': 'Positive', 'score': 0.044191230088472366}]]
# [[{'label': 'Negative', 'score': 0.1697527915239334}, {'label': 'Neutral', 'score': 0.672252893447876}, {'label': 'Positive', 'score': 0.1579943150281906}]]
# [[{'label': 'Negative', 'score': 0.005011467263102531}, {'label': 'Neutral', 'score': 0.38701480627059937}, {'label': 'Positive', 'score': 0.6079736948013306}]]
# [[{'label': 'Negative', 'score': 0.043713636696338654}, {'label': 'Neutral', 'score': 0.7799250483512878}, {'label': 'Positive', 'score': 0.1763612926006317}]]
# [[{'label': 'Negative', 'score': 0.019736817106604576}, {'label': 'Neutral', 'score': 0.7931993007659912}, {'label': 'Positive', 'score': 0.1870637983083725}]]
# [[{'label': 'Negative', 'score': 0.003332543885335326}, {'label': 'Neutral', 'score': 0.49031707644462585}, {'label': 'Positive', 'score': 0.5063503384590149}]]
# [[{'label': 'Negative', 'score': 0.016732538118958473}, {'label': 'Neutral', 'score': 0.751477062702179}, {'label': 'Positive', 'score': 0.2317904382944107}]]
# [[{'label': 'Negative', 'score': 0.003300874261185527}, {'label': 'Neutral', 'score': 0.16651973128318787}, {'label': 'Positive', 'score': 0.8301793932914734}]]
# [[{'label': 'Negative', 'score': 0.007132618222385645}, {'label': 'Neutral', 'score': 0.7613351941108704}, {'label': 'Positive', 'score': 0.2315322458744049}]]
# [[{'label': 'Negative', 'score': 0.7980422973632812}, {'label': 'Neutral', 'score': 0.18445244431495667}, {'label': 'Positive', 'score': 0.017505209892988205}]]
# [[{'label': 'Negative', 'score': 0.3081851601600647}, {'label': 'Neutral', 'score': 0.5400014519691467}, {'label': 'Positive', 'score': 0.15181340277194977}]]
# [[{'label': 'Negative', 'score': 0.014468375593423843}, {'label': 'Neutral', 'score': 0.7457369565963745}, {'label': 'Positive', 'score': 0.23979467153549194}]]
# [[{'label': 'Negative', 'score': 0.05838625133037567}, {'label': 'Neutral', 'score': 0.856593906879425}, {'label': 'Positive', 'score': 0.08501985669136047}]]
# [[{'label': 'Negative', 'score': 0.054579149931669235}, {'label': 'Neutral', 'score': 0.8556036949157715}, {'label': 'Positive', 'score': 0.08981716632843018}]]
# [[{'label': 'Negative', 'score': 0.5899535417556763}, {'label': 'Neutral', 'score': 0.3875162601470947}, {'label': 'Positive', 'score': 0.022530244663357735}]]
# [[{'label': 'Negative', 'score': 0.10598309338092804}, {'label': 'Neutral', 'score': 0.8468703031539917}, {'label': 'Positive', 'score': 0.04714660719037056}]]
# [[{'label': 'Negative', 'score': 0.0065228561870753765}, {'label': 'Neutral', 'score': 0.06067371740937233}, {'label': 'Positive', 'score': 0.9328034520149231}]]
# [[{'label': 'Negative', 'score': 0.33233124017715454}, {'label': 'Neutral', 'score': 0.6010903120040894}, {'label': 'Positive', 'score': 0.06657839566469193}]]
# [[{'label': 'Negative', 'score': 0.7045062780380249}, {'label': 'Neutral', 'score': 0.28173211216926575}, {'label': 'Positive', 'score': 0.013761588372290134}]]
# [[{'label': 'Negative', 'score': 0.6420676708221436}, {'label': 'Neutral', 'score': 0.342969685792923}, {'label': 'Positive', 'score': 0.014962640590965748}]]
# [[{'label': 'Negative', 'score': 0.17095720767974854}, {'label': 'Neutral', 'score': 0.6554408669471741}, {'label': 'Positive', 'score': 0.17360195517539978}]]
# [[{'label': 'Negative', 'score': 0.013931161724030972}, {'label': 'Neutral', 'score': 0.6842688322067261}, {'label': 'Positive', 'score': 0.30180004239082336}]]
# [[{'label': 'Negative', 'score': 0.7848484516143799}, {'label': 'Neutral', 'score': 0.19538763165473938}, {'label': 'Positive', 'score': 0.019763892516493797}]]
# [[{'label': 'Negative', 'score': 0.19731101393699646}, {'label': 'Neutral', 'score': 0.7606244683265686}, {'label': 'Positive', 'score': 0.04206448048353195}]]
# [[{'label': 'Negative', 'score': 0.032536618411540985}, {'label': 'Neutral', 'score': 0.33821526169776917}, {'label': 'Positive', 'score': 0.6292481422424316}]]
# [[{'label': 'Negative', 'score': 0.4393036663532257}, {'label': 'Neutral', 'score': 0.5341378450393677}, {'label': 'Positive', 'score': 0.02655843272805214}]]
# [[{'label': 'Negative', 'score': 0.007625326048582792}, {'label': 'Neutral', 'score': 0.6167990565299988}, {'label': 'Positive', 'score': 0.3755756616592407}]]
# [[{'label': 'Negative', 'score': 0.507529079914093}, {'label': 'Neutral', 'score': 0.4710223376750946}, {'label': 'Positive', 'score': 0.02144862338900566}]]
# [[{'label': 'Negative', 'score': 0.06361597031354904}, {'label': 'Neutral', 'score': 0.7885991334915161}, {'label': 'Positive', 'score': 0.14778487384319305}]]
# [[{'label': 'Negative', 'score': 0.4831318259239197}, {'label': 'Neutral', 'score': 0.4643537402153015}, {'label': 'Positive', 'score': 0.05251450464129448}]]
# [[{'label': 'Negative', 'score': 0.011193331331014633}, {'label': 'Neutral', 'score': 0.30943435430526733}, {'label': 'Positive', 'score': 0.6793723106384277}]]
# [[{'label': 'Negative', 'score': 0.024564865976572037}, {'label': 'Neutral', 'score': 0.9438777565956116}, {'label': 'Positive', 'score': 0.03155730664730072}]]
# [[{'label': 'Negative', 'score': 0.026995612308382988}, {'label': 'Neutral', 'score': 0.5451475381851196}, {'label': 'Positive', 'score': 0.4278569221496582}]]
# [[{'label': 'Negative', 'score': 0.018767105415463448}, {'label': 'Neutral', 'score': 0.07126320153474808}, {'label': 'Positive', 'score': 0.9099696278572083}]]
# [[{'label': 'Negative', 'score': 0.01029124390333891}, {'label': 'Neutral', 'score': 0.8833725452423096}, {'label': 'Positive', 'score': 0.10633622109889984}]]
# [[{'label': 'Negative', 'score': 0.8065617084503174}, {'label': 'Neutral', 'score': 0.183757022023201}, {'label': 'Positive', 'score': 0.009681311435997486}]]
# [[{'label': 'Negative', 'score': 0.010375593788921833}, {'label': 'Neutral', 'score': 0.8132651448249817}, {'label': 'Positive', 'score': 0.17635928094387054}]]
# [[{'label': 'Negative', 'score': 0.17670941352844238}, {'label': 'Neutral', 'score': 0.7977471351623535}, {'label': 'Positive', 'score': 0.025543419644236565}]]
# [[{'label': 'Negative', 'score': 0.04467368498444557}, {'label': 'Neutral', 'score': 0.913349986076355}, {'label': 'Positive', 'score': 0.04197636991739273}]]
# [[{'label': 'Negative', 'score': 0.018588697537779808}, {'label': 'Neutral', 'score': 0.8514333963394165}, {'label': 'Positive', 'score': 0.12997791171073914}]]
# [[{'label': 'Negative', 'score': 0.005700856447219849}, {'label': 'Neutral', 'score': 0.15002083778381348}, {'label': 'Positive', 'score': 0.8442782759666443}]]
# [[{'label': 'Negative', 'score': 0.009591280482709408}, {'label': 'Neutral', 'score': 0.41951102018356323}, {'label': 'Positive', 'score': 0.5708977580070496}]]
# [[{'label': 'Negative', 'score': 0.02107599750161171}, {'label': 'Neutral', 'score': 0.823977530002594}, {'label': 'Positive', 'score': 0.15494641661643982}]]
# [[{'label': 'Negative', 'score': 0.01602805405855179}, {'label': 'Neutral', 'score': 0.7723386287689209}, {'label': 'Positive', 'score': 0.21163330972194672}]]
# [[{'label': 'Negative', 'score': 0.01846165768802166}, {'label': 'Neutral', 'score': 0.902801513671875}, {'label': 'Positive', 'score': 0.0787367895245552}]]
# [[{'label': 'Negative', 'score': 0.05191594362258911}, {'label': 'Neutral', 'score': 0.8498127460479736}, {'label': 'Positive', 'score': 0.09827128052711487}]]
# [[{'label': 'Negative', 'score': 0.511748194694519}, {'label': 'Neutral', 'score': 0.4404834508895874}, {'label': 'Positive', 'score': 0.04776836559176445}]]
# [[{'label': 'negative', 'score': 5.776581383543089e-05}, {'label': 'neutral', 'score': 0.9998987913131714}, {'label': 'positive', 'score': 4.340518353274092e-05}]]
# [[{'label': 'negative', 'score': 5.776581383543089e-05}, {'label': 'neutral', 'score': 0.9998987913131714}, {'label': 'positive', 'score': 4.340518353274092e-05}]]
# [[{'label': 'negative', 'score': 0.00017636896518524736}, {'label': 'neutral', 'score': 0.9997851252555847}, {'label': 'positive', 'score': 3.8437076000263914e-05}]]
# [[{'label': 'negative', 'score': 0.000694016576744616}, {'label': 'neutral', 'score': 0.00962228886783123}, {'label': 'positive', 'score': 0.9896836280822754}]]
# [[{'label': 'negative', 'score': 7.92977589298971e-05}, {'label': 'neutral', 'score': 0.9998113512992859}, {'label': 'positive', 'score': 0.00010936767648672685}]]
# [[{'label': 'negative', 'score': 6.529488018713892e-05}, {'label': 'neutral', 'score': 0.9998700618743896}, {'label': 'positive', 'score': 6.465343903983012e-05}]]
# [[{'label': 'negative', 'score': 8.647391950944439e-05}, {'label': 'neutral', 'score': 0.9990253448486328}, {'label': 'positive', 'score': 0.0008881613612174988}]]
# [[{'label': 'negative', 'score': 6.295532512012869e-05}, {'label': 'neutral', 'score': 0.9998893737792969}, {'label': 'positive', 'score': 4.768401413457468e-05}]]
# [[{'label': 'negative', 'score': 7.718106644460931e-05}, {'label': 'neutral', 'score': 0.999799907207489}, {'label': 'positive', 'score': 0.00012287654681131244}]]
# [[{'label': 'negative', 'score': 6.2898026953917e-05}, {'label': 'neutral', 'score': 0.9998714923858643}, {'label': 'positive', 'score': 6.550621765200049e-05}]]
# [[{'label': 'negative', 'score': 6.709278386551887e-05}, {'label': 'neutral', 'score': 0.9998655319213867}, {'label': 'positive', 'score': 6.73865361022763e-05}]]
# [[{'label': 'negative', 'score': 6.637083424720913e-05}, {'label': 'neutral', 'score': 0.999871015548706}, {'label': 'positive', 'score': 6.260499503696337e-05}]]
# [[{'label': 'negative', 'score': 9.281367965741083e-05}, {'label': 'neutral', 'score': 0.9997572302818298}, {'label': 'positive', 'score': 0.00014998746337369084}]]
# [[{'label': 'negative', 'score': 9.575598232913762e-05}, {'label': 'neutral', 'score': 0.9998431205749512}, {'label': 'positive', 'score': 6.115917494753376e-05}]]
# [[{'label': 'negative', 'score': 0.0023579334374517202}, {'label': 'neutral', 'score': 0.07556920498609543}, {'label': 'positive', 'score': 0.9220728874206543}]]
# [[{'label': 'negative', 'score': 7.279009878402576e-05}, {'label': 'neutral', 'score': 0.9998689889907837}, {'label': 'positive', 'score': 5.819010402774438e-05}]]
# [[{'label': 'negative', 'score': 0.0002906440931838006}, {'label': 'neutral', 'score': 0.0002447216247674078}, {'label': 'positive', 'score': 0.9994646906852722}]]
# [[{'label': 'negative', 'score': 0.0017550140619277954}, {'label': 'neutral', 'score': 0.4232091009616852}, {'label': 'positive', 'score': 0.5750358700752258}]]
# [[{'label': 'negative', 'score': 0.9858469367027283}, {'label': 'neutral', 'score': 0.013691160827875137}, {'label': 'positive', 'score': 0.0004619163228198886}]]
# [[{'label': 'negative', 'score': 0.0828566923737526}, {'label': 'neutral', 'score': 0.7537068724632263}, {'label': 'positive', 'score': 0.1634363830089569}]]
# [[{'label': 'negative', 'score': 6.504912016680464e-05}, {'label': 'neutral', 'score': 0.9998832941055298}, {'label': 'positive', 'score': 5.1610888476716354e-05}]]
# [[{'label': 'negative', 'score': 5.9583140682661906e-05}, {'label': 'neutral', 'score': 0.9993365406990051}, {'label': 'positive', 'score': 0.0006038534920662642}]]
# [[{'label': 'negative', 'score': 6.79912482155487e-05}, {'label': 'neutral', 'score': 0.9998786449432373}, {'label': 'positive', 'score': 5.338068513083272e-05}]]
# [[{'label': 'negative', 'score': 6.328447489067912e-05}, {'label': 'neutral', 'score': 0.9998846054077148}, {'label': 'positive', 'score': 5.208548827795312e-05}]]
# [[{'label': 'negative', 'score': 0.9977497458457947}, {'label': 'neutral', 'score': 0.0015307692810893059}, {'label': 'positive', 'score': 0.0007194211357273161}]]
# [[{'label': 'negative', 'score': 0.02415427565574646}, {'label': 'neutral', 'score': 0.9752809405326843}, {'label': 'positive', 'score': 0.0005647483631037176}]]
# [[{'label': 'negative', 'score': 0.000917889759875834}, {'label': 'neutral', 'score': 0.721545398235321}, {'label': 'positive', 'score': 0.2775367200374603}]]
# [[{'label': 'negative', 'score': 0.9982287287712097}, {'label': 'neutral', 'score': 0.0011418391950428486}, {'label': 'positive', 'score': 0.0006294916965998709}]]
# [[{'label': 'negative', 'score': 0.005325117614120245}, {'label': 'neutral', 'score': 0.9942726492881775}, {'label': 'positive', 'score': 0.00040221333620138466}]]
# [[{'label': 'negative', 'score': 0.00019545343820936978}, {'label': 'neutral', 'score': 0.00043332570930942893}, {'label': 'positive', 'score': 0.9993712306022644}]]
# [[{'label': 'negative', 'score': 0.0001731535157887265}, {'label': 'neutral', 'score': 0.0004606752481777221}, {'label': 'positive', 'score': 0.9993662238121033}]]
# [[{'label': 'negative', 'score': 5.757182225352153e-05}, {'label': 'neutral', 'score': 0.9998756647109985}, {'label': 'positive', 'score': 6.677461351500824e-05}]]
# [[{'label': 'negative', 'score': 0.0009241735679097474}, {'label': 'neutral', 'score': 0.8520656824111938}, {'label': 'positive', 'score': 0.14701013267040253}]]
# [[{'label': 'negative', 'score': 6.124637729953974e-05}, {'label': 'neutral', 'score': 0.9998831748962402}, {'label': 'positive', 'score': 5.551341382670216e-05}]]
# [[{'label': 'negative', 'score': 0.00013444801152218133}, {'label': 'neutral', 'score': 0.9997991919517517}, {'label': 'positive', 'score': 6.634942110395059e-05}]]
# [[{'label': 'negative', 'score': 0.00012549675011541694}, {'label': 'neutral', 'score': 0.998045802116394}, {'label': 'positive', 'score': 0.001828618347644806}]]
# [[{'label': 'negative', 'score': 0.0001543645339552313}, {'label': 'neutral', 'score': 0.0002584752219263464}, {'label': 'positive', 'score': 0.9995871186256409}]]
# [[{'label': 'negative', 'score': 6.554432184202597e-05}, {'label': 'neutral', 'score': 0.9998711347579956}, {'label': 'positive', 'score': 6.334871432045475e-05}]]
# [[{'label': 'negative', 'score': 0.00011731485574273393}, {'label': 'neutral', 'score': 0.9990605711936951}, {'label': 'positive', 'score': 0.0008221123716793954}]]
# [[{'label': 'negative', 'score': 0.00026454852195456624}, {'label': 'neutral', 'score': 0.0004275828832760453}, {'label': 'positive', 'score': 0.9993078708648682}]]
# [[{'label': 'negative', 'score': 6.550682883244008e-05}, {'label': 'neutral', 'score': 0.9998854398727417}, {'label': 'positive', 'score': 4.903694207314402e-05}]]
# [[{'label': 'negative', 'score': 5.641995812766254e-05}, {'label': 'neutral', 'score': 0.999609649181366}, {'label': 'positive', 'score': 0.0003339810064062476}]]
# [[{'label': 'negative', 'score': 6.696818309137598e-05}, {'label': 'neutral', 'score': 0.9998350143432617}, {'label': 'positive', 'score': 9.798457176657394e-05}]]
# [[{'label': 'negative', 'score': 9.771683835424483e-05}, {'label': 'neutral', 'score': 0.9998358488082886}, {'label': 'positive', 'score': 6.642720109084621e-05}]]
# [[{'label': 'negative', 'score': 0.00016471167327836156}, {'label': 'neutral', 'score': 0.9975684285163879}, {'label': 'positive', 'score': 0.002266851719468832}]]
# [[{'label': 'negative', 'score': 6.126766675151885e-05}, {'label': 'neutral', 'score': 0.999819815158844}, {'label': 'positive', 'score': 0.00011900529352715239}]]
# [[{'label': 'negative', 'score': 5.711481935577467e-05}, {'label': 'neutral', 'score': 0.9998520612716675}, {'label': 'positive', 'score': 9.082760516321287e-05}]]
# [[{'label': 'negative', 'score': 0.0008467404986731708}, {'label': 'neutral', 'score': 0.8530541658401489}, {'label': 'positive', 'score': 0.1460990160703659}]]
# [[{'label': 'negative', 'score': 0.024424711242318153}, {'label': 'neutral', 'score': 0.7841614484786987}, {'label': 'positive', 'score': 0.1914137899875641}]]
# [[{'label': 'negative', 'score': 5.945898737991229e-05}, {'label': 'neutral', 'score': 0.9998940229415894}, {'label': 'positive', 'score': 4.648665708373301e-05}]]
# [[{'label': 'negative', 'score': 0.0001599976239958778}, {'label': 'neutral', 'score': 0.0001307445199927315}, {'label': 'positive', 'score': 0.9997091889381409}]]
# [[{'label': 'negative', 'score': 7.063700468279421e-05}, {'label': 'neutral', 'score': 0.9998648166656494}, {'label': 'positive', 'score': 6.448984640883282e-05}]]
# [[{'label': 'negative', 'score': 8.37749321362935e-05}, {'label': 'neutral', 'score': 0.9998559951782227}, {'label': 'positive', 'score': 6.020619912305847e-05}]]
# [[{'label': 'negative', 'score': 0.0007234415388666093}, {'label': 'neutral', 'score': 0.9992057681083679}, {'label': 'positive', 'score': 7.085186371114105e-05}]]
# [[{'label': 'negative', 'score': 7.567150896647945e-05}, {'label': 'neutral', 'score': 0.9998781681060791}, {'label': 'positive', 'score': 4.6118671889416873e-05}]]
# [[{'label': 'negative', 'score': 6.731630128342658e-05}, {'label': 'neutral', 'score': 0.9998574256896973}, {'label': 'positive', 'score': 7.525269029429182e-05}]]
# [[{'label': 'negative', 'score': 0.0016479658661410213}, {'label': 'neutral', 'score': 0.9982931017875671}, {'label': 'positive', 'score': 5.8906865888275206e-05}]]
# ...
# [[{'label': 'Negative', 'score': 0.1098322793841362}, {'label': 'Neutral', 'score': 0.8391729593276978}, {'label': 'Positive', 'score': 0.05099480599164963}]]
# [[{'label': 'Negative', 'score': 0.00909578800201416}, {'label': 'Neutral', 'score': 0.9480764865875244}, {'label': 'Positive', 'score': 0.042827755212783813}]]
# [[{'label': 'Negative', 'score': 0.003231430659070611}, {'label': 'Neutral', 'score': 0.5078704953193665}, {'label': 'Positive', 'score': 0.48889803886413574}]]
# [[{'label': 'Negative', 'score': 0.08147630095481873}, {'label': 'Neutral', 'score': 0.8849953413009644}, {'label': 'Positive', 'score': 0.03352833539247513}]]
# [[{'label': 'Negative', 'score': 0.008994469419121742}, {'label': 'Neutral', 'score': 0.7352941632270813}, {'label': 'Positive', 'score': 0.2557113468647003}]]
# [[{'label': 'Negative', 'score': 0.8368222713470459}, {'label': 'Neutral', 'score': 0.14138652384281158}, {'label': 'Positive', 'score': 0.02179117687046528}]]
# [[{'label': 'Negative', 'score': 0.012728827074170113}, {'label': 'Neutral', 'score': 0.8374701142311096}, {'label': 'Positive', 'score': 0.14980104565620422}]]
# [[{'label': 'Negative', 'score': 0.0175703726708889}, {'label': 'Neutral', 'score': 0.9498907923698425}, {'label': 'Positive', 'score': 0.032538894563913345}]]
# [[{'label': 'Negative', 'score': 0.006301373243331909}, {'label': 'Neutral', 'score': 0.3022370934486389}, {'label': 'Positive', 'score': 0.6914615035057068}]]
# [[{'label': 'Negative', 'score': 0.01379209291189909}, {'label': 'Neutral', 'score': 0.046655040234327316}, {'label': 'Positive', 'score': 0.9395528435707092}]]
# [[{'label': 'Negative', 'score': 0.3967230021953583}, {'label': 'Neutral', 'score': 0.5356613397598267}, {'label': 'Positive', 'score': 0.06761567294597626}]]
# [[{'label': 'Negative', 'score': 0.19964328408241272}, {'label': 'Neutral', 'score': 0.7587981820106506}, {'label': 'Positive', 'score': 0.041558537632226944}]]
# [[{'label': 'Negative', 'score': 0.1636504977941513}, {'label': 'Neutral', 'score': 0.7894110679626465}, {'label': 'Positive', 'score': 0.046938374638557434}]]
# [[{'label': 'Negative', 'score': 0.007391294464468956}, {'label': 'Neutral', 'score': 0.588420033454895}, {'label': 'Positive', 'score': 0.40418872237205505}]]
# [[{'label': 'Negative', 'score': 0.2833287715911865}, {'label': 'Neutral', 'score': 0.6766575574874878}, {'label': 'Positive', 'score': 0.0400136299431324}]]
# [[{'label': 'negative', 'score': 0.9959452748298645}, {'label': 'neutral', 'score': 0.0032877635676413774}, {'label': 'positive', 'score': 0.0007669255719520152}]]
# [[{'label': 'negative', 'score': 0.9959452748298645}, {'label': 'neutral', 'score': 0.0032877635676413774}, {'label': 'positive', 'score': 0.0007669255719520152}]]
# [[{'label': 'negative', 'score': 0.9984594583511353}, {'label': 'neutral', 'score': 0.0009576726006343961}, {'label': 'positive', 'score': 0.0005828648572787642}]]
# [[{'label': 'negative', 'score': 0.9980092644691467}, {'label': 'neutral', 'score': 0.0015617326134815812}, {'label': 'positive', 'score': 0.0004289954958949238}]]
# [[{'label': 'negative', 'score': 6.323611160041764e-05}, {'label': 'neutral', 'score': 0.9998868703842163}, {'label': 'positive', 'score': 4.983018516213633e-05}]]
# [[{'label': 'negative', 'score': 0.9864066243171692}, {'label': 'neutral', 'score': 0.0015770437894389033}, {'label': 'positive', 'score': 0.012016233056783676}]]
# [[{'label': 'negative', 'score': 0.7993620038032532}, {'label': 'neutral', 'score': 0.199834406375885}, {'label': 'positive', 'score': 0.000803563161753118}]]
# [[{'label': 'negative', 'score': 0.00011123347212560475}, {'label': 'neutral', 'score': 0.9998262524604797}, {'label': 'positive', 'score': 6.257646600715816e-05}]]
# [[{'label': 'negative', 'score': 6.206892430782318e-05}, {'label': 'neutral', 'score': 0.9998781681060791}, {'label': 'positive', 'score': 5.970112033537589e-05}]]
# [[{'label': 'negative', 'score': 0.005924903322011232}, {'label': 'neutral', 'score': 0.994016170501709}, {'label': 'positive', 'score': 5.894244895898737e-05}]]
# [[{'label': 'negative', 'score': 0.00030614843126386404}, {'label': 'neutral', 'score': 0.9996296167373657}, {'label': 'positive', 'score': 6.420708086807281e-05}]]
# [[{'label': 'negative', 'score': 5.789367060060613e-05}, {'label': 'neutral', 'score': 0.9998571872711182}, {'label': 'positive', 'score': 8.48260970087722e-05}]]
# [[{'label': 'negative', 'score': 4.671972055803053e-05}, {'label': 'neutral', 'score': 0.9995384216308594}, {'label': 'positive', 'score': 0.00041488505667075515}]]
# [[{'label': 'negative', 'score': 0.998621940612793}, {'label': 'neutral', 'score': 0.0008140667341649532}, {'label': 'positive', 'score': 0.0005640408489853144}]]
# [[{'label': 'negative', 'score': 0.016169443726539612}, {'label': 'neutral', 'score': 0.0019474341534078121}, {'label': 'positive', 'score': 0.9818830490112305}]]
# [[{'label': 'negative', 'score': 0.0004303268506191671}, {'label': 'neutral', 'score': 0.08237864077091217}, {'label': 'positive', 'score': 0.9171910285949707}]]
# [[{'label': 'negative', 'score': 6.274271436268464e-05}, {'label': 'neutral', 'score': 0.9998825788497925}, {'label': 'positive', 'score': 5.474088175105862e-05}]]
# [[{'label': 'negative', 'score': 0.0001060255744960159}, {'label': 'neutral', 'score': 0.9955111742019653}, {'label': 'positive', 'score': 0.004382831044495106}]]
# [[{'label': 'negative', 'score': 5.697949745808728e-05}, {'label': 'neutral', 'score': 0.999875545501709}, {'label': 'positive', 'score': 6.75161209073849e-05}]]
# [[{'label': 'negative', 'score': 0.00010043513611890376}, {'label': 'neutral', 'score': 0.9992497563362122}, {'label': 'positive', 'score': 0.0006498107104562223}]]
# [[{'label': 'negative', 'score': 0.11415714025497437}, {'label': 'neutral', 'score': 0.29717808961868286}, {'label': 'positive', 'score': 0.5886647701263428}]]
# [[{'label': 'negative', 'score': 6.838181434432045e-05}, {'label': 'neutral', 'score': 0.9997338652610779}, {'label': 'positive', 'score': 0.00019773503299802542}]]
# [[{'label': 'negative', 'score': 8.051530312513933e-05}, {'label': 'neutral', 'score': 0.9998651742935181}, {'label': 'positive', 'score': 5.424328628578223e-05}]]
# [[{'label': 'negative', 'score': 6.522415060317144e-05}, {'label': 'neutral', 'score': 0.9998838901519775}, {'label': 'positive', 'score': 5.086540841148235e-05}]]
# [[{'label': 'negative', 'score': 6.407553155440837e-05}, {'label': 'neutral', 'score': 0.9998169541358948}, {'label': 'positive', 'score': 0.0001189903196063824}]]
# [[{'label': 'negative', 'score': 7.144944538595155e-05}, {'label': 'neutral', 'score': 0.9998806715011597}, {'label': 'positive', 'score': 4.791009268956259e-05}]]
# [[{'label': 'negative', 'score': 5.3500785725191236e-05}, {'label': 'neutral', 'score': 0.9998791217803955}, {'label': 'positive', 'score': 6.734260387020186e-05}]]
# [[{'label': 'negative', 'score': 0.9908313155174255}, {'label': 'neutral', 'score': 0.003570055589079857}, {'label': 'positive', 'score': 0.005598634015768766}]]
# [[{'label': 'negative', 'score': 0.00015845648886170238}, {'label': 'neutral', 'score': 0.0002496522502042353}, {'label': 'positive', 'score': 0.9995918869972229}]]
# [[{'label': 'negative', 'score': 8.051511395024136e-05}, {'label': 'neutral', 'score': 0.9998581409454346}, {'label': 'positive', 'score': 6.122965714894235e-05}]]
# [[{'label': 'negative', 'score': 0.00024046204634942114}, {'label': 'neutral', 'score': 0.0001463978987885639}, {'label': 'positive', 'score': 0.9996132254600525}]]
# [[{'label': 'negative', 'score': 0.0007664933218620718}, {'label': 'neutral', 'score': 0.022495858371257782}, {'label': 'positive', 'score': 0.9767376780509949}]]
# [[{'label': 'negative', 'score': 5.6933822634164244e-05}, {'label': 'neutral', 'score': 0.999890923500061}, {'label': 'positive', 'score': 5.209545633988455e-05}]]
# [[{'label': 'negative', 'score': 8.059500396484509e-05}, {'label': 'neutral', 'score': 0.9998732805252075}, {'label': 'positive', 'score': 4.6073600969975814e-05}]]
# [[{'label': 'negative', 'score': 7.393612031592056e-05}, {'label': 'neutral', 'score': 0.9998331069946289}, {'label': 'positive', 'score': 9.298658551415429e-05}]]
# [[{'label': 'negative', 'score': 0.00019052410789299756}, {'label': 'neutral', 'score': 0.0002660111349541694}, {'label': 'positive', 'score': 0.9995434880256653}]]
# [[{'label': 'negative', 'score': 0.003252825466915965}, {'label': 'neutral', 'score': 0.3891153037548065}, {'label': 'positive', 'score': 0.6076318621635437}]]
# [[{'label': 'NEGATIVE', 'score': 0.9980323910713196}, {'label': 'POSITIVE', 'score': 0.0019675788935273886}]]
# [[{'label': 'NEGATIVE', 'score': 0.9980323910713196}, {'label': 'POSITIVE', 'score': 0.0019675788935273886}]]
# [[{'label': 'NEGATIVE', 'score': 0.9997274279594421}, {'label': 'POSITIVE', 'score': 0.00027261636569164693}]]
# [[{'label': 'NEGATIVE', 'score': 0.9974260926246643}, {'label': 'POSITIVE', 'score': 0.002573927864432335}]]
# [[{'label': 'NEGATIVE', 'score': 0.8295396566390991}, {'label': 'POSITIVE', 'score': 0.17046035826206207}]]
# [[{'label': 'NEGATIVE', 'score': 0.9994373917579651}, {'label': 'POSITIVE', 'score': 0.0005625543417409062}]]
# [[{'label': 'NEGATIVE', 'score': 0.8458854556083679}, {'label': 'POSITIVE', 'score': 0.15411458909511566}]]
# [[{'label': 'NEGATIVE', 'score': 0.7552130222320557}, {'label': 'POSITIVE', 'score': 0.24478694796562195}]]
# [[{'label': 'NEGATIVE', 'score': 0.9531921148300171}, {'label': 'POSITIVE', 'score': 0.046807900071144104}]]
# [[{'label': 'NEGATIVE', 'score': 0.9887439012527466}, {'label': 'POSITIVE', 'score': 0.011256048455834389}]]
# [[{'label': 'NEGATIVE', 'score': 0.9953538179397583}, {'label': 'POSITIVE', 'score': 0.004646208602935076}]]
# [[{'label': 'NEGATIVE', 'score': 0.9224605560302734}, {'label': 'POSITIVE', 'score': 0.07753944396972656}]]
# [[{'label': 'NEGATIVE', 'score': 0.041190892457962036}, {'label': 'POSITIVE', 'score': 0.9588090777397156}]]
# [[{'label': 'NEGATIVE', 'score': 0.9996929168701172}, {'label': 'POSITIVE', 'score': 0.00030706546385772526}]]
# [[{'label': 'NEGATIVE', 'score': 0.008120348677039146}, {'label': 'POSITIVE', 'score': 0.9918796420097351}]]
# [[{'label': 'NEGATIVE', 'score': 0.0036756424233317375}, {'label': 'POSITIVE', 'score': 0.996324360370636}]]
# [[{'label': 'NEGATIVE', 'score': 0.0005051367334090173}, {'label': 'POSITIVE', 'score': 0.9994947910308838}]]
# [[{'label': 'NEGATIVE', 'score': 0.0016738113481551409}, {'label': 'POSITIVE', 'score': 0.9983262419700623}]]
# [[{'label': 'NEGATIVE', 'score': 0.9918603301048279}, {'label': 'POSITIVE', 'score': 0.008139709942042828}]]
# [[{'label': 'NEGATIVE', 'score': 0.0003173980221617967}, {'label': 'POSITIVE', 'score': 0.9996826648712158}]]
# [[{'label': 'NEGATIVE', 'score': 0.9724087119102478}, {'label': 'POSITIVE', 'score': 0.027591267600655556}]]
# [[{'label': 'NEGATIVE', 'score': 0.0003081364557147026}, {'label': 'POSITIVE', 'score': 0.9996918439865112}]]
# [[{'label': 'NEGATIVE', 'score': 0.10828455537557602}, {'label': 'POSITIVE', 'score': 0.8917154669761658}]]
# [[{'label': 'NEGATIVE', 'score': 0.9939972162246704}, {'label': 'POSITIVE', 'score': 0.006002744659781456}]]
# [[{'label': 'NEGATIVE', 'score': 0.9957442879676819}, {'label': 'POSITIVE', 'score': 0.004255759064108133}]]
# [[{'label': 'NEGATIVE', 'score': 0.9947199821472168}, {'label': 'POSITIVE', 'score': 0.005279965698719025}]]
# [[{'label': 'NEGATIVE', 'score': 0.022470736876130104}, {'label': 'POSITIVE', 'score': 0.9775292873382568}]]
# [[{'label': 'NEGATIVE', 'score': 0.9997085928916931}, {'label': 'POSITIVE', 'score': 0.0002914223005063832}]]
# [[{'label': 'NEGATIVE', 'score': 0.02514421008527279}, {'label': 'POSITIVE', 'score': 0.9748558402061462}]]
# [[{'label': 'NEGATIVE', 'score': 0.9885508418083191}, {'label': 'POSITIVE', 'score': 0.011449139565229416}]]
# [[{'label': 'NEGATIVE', 'score': 0.0021034451201558113}, {'label': 'POSITIVE', 'score': 0.9978965520858765}]]
# [[{'label': 'NEGATIVE', 'score': 0.01953352987766266}, {'label': 'POSITIVE', 'score': 0.9804664254188538}]]
# [[{'label': 'NEGATIVE', 'score': 0.9966797828674316}, {'label': 'POSITIVE', 'score': 0.003320220857858658}]]
# [[{'label': 'NEGATIVE', 'score': 0.9982788562774658}, {'label': 'POSITIVE', 'score': 0.00172119599301368}]]
# [[{'label': 'NEGATIVE', 'score': 0.9952115416526794}, {'label': 'POSITIVE', 'score': 0.004788456484675407}]]
# [[{'label': 'NEGATIVE', 'score': 0.9989681243896484}, {'label': 'POSITIVE', 'score': 0.0010319410357624292}]]
# [[{'label': 'NEGATIVE', 'score': 0.9889748096466064}, {'label': 'POSITIVE', 'score': 0.011025206185877323}]]
# [[{'label': 'Negative', 'score': 0.1387639045715332}, {'label': 'Neutral', 'score': 0.7350621819496155}, {'label': 'Positive', 'score': 0.12617400288581848}]]
# [[{'label': 'Negative', 'score': 0.1387639045715332}, {'label': 'Neutral', 'score': 0.7350621819496155}, {'label': 'Positive', 'score': 0.12617400288581848}]]
# [[{'label': 'Negative', 'score': 0.5387263298034668}, {'label': 'Neutral', 'score': 0.4479115605354309}, {'label': 'Positive', 'score': 0.013362095691263676}]]
# [[{'label': 'Negative', 'score': 0.041513409465551376}, {'label': 'Neutral', 'score': 0.9220317602157593}, {'label': 'Positive', 'score': 0.03645481914281845}]]
# [[{'label': 'Negative', 'score': 0.08027707040309906}, {'label': 'Neutral', 'score': 0.9046199917793274}, {'label': 'Positive', 'score': 0.015103009529411793}]]
# [[{'label': 'negative', 'score': 0.00013442263298202306}, {'label': 'neutral', 'score': 0.9997028708457947}, {'label': 'positive', 'score': 0.00016273099754471332}]]
# [[{'label': 'negative', 'score': 0.00013442263298202306}, {'label': 'neutral', 'score': 0.9997028708457947}, {'label': 'positive', 'score': 0.00016273099754471332}]]
# [[{'label': 'negative', 'score': 0.00016324959869962186}, {'label': 'neutral', 'score': 0.9996880292892456}, {'label': 'positive', 'score': 0.00014872323663439602}]]
# [[{'label': 'negative', 'score': 0.0008473866037093103}, {'label': 'neutral', 'score': 0.9988221526145935}, {'label': 'positive', 'score': 0.00033041994902305305}]]
# [[{'label': 'negative', 'score': 9.552268602419645e-05}, {'label': 'neutral', 'score': 0.9998403787612915}, {'label': 'positive', 'score': 6.41740916762501e-05}]]
# [[{'label': 'NEGATIVE', 'score': 0.9990578293800354}, {'label': 'POSITIVE', 'score': 0.0009421823197044432}]]
# [[{'label': 'NEGATIVE', 'score': 0.9990578293800354}, {'label': 'POSITIVE', 'score': 0.0009421823197044432}]]
# [[{'label': 'NEGATIVE', 'score': 0.9994317889213562}, {'label': 'POSITIVE', 'score': 0.0005682164337486029}]]
# [[{'label': 'NEGATIVE', 'score': 0.978384256362915}, {'label': 'POSITIVE', 'score': 0.021615704521536827}]]
# [[{'label': 'NEGATIVE', 'score': 0.9791562557220459}, {'label': 'POSITIVE', 'score': 0.02084370143711567}]]
# /shared-libs/python3.7/py/lib/python3.7/site-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /shared-libs/python3.7/py/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-14-54d4ae16f1ea> in <module>
# ----> 1 output = process_Twitter(raw_data)
#
# <ipython-input-13-2185b393d040> in process_Twitter(data)
#      11     for ticker in tickers:
#      12         mention_count, stock, top20tweets, just20tweets = run_model(dataDic[ticker])
# ---> 13         results = process_Sentiment(stock)
#      14
#      15         mentions.append(mention_count)
#
# <ipython-input-12-8e432dd455d5> in process_Sentiment(sentimment_Data)
#      18     weighted_neg, weighted_pos = neg_avg * neg_weight, pos_avg * pos_weight
#      19
# ---> 20     if (num_neg / num_pos) > 0.75 and (num_neg / num_pos) < 1.25:
#      21         sentimment_ratio = neg_avg / pos_avg
#      22     else:
#
# ZeroDivisionError: division by zero

# %%
output
# Out:
#    Ticker  Mentions  Negative Average  Positive Average Overall Sentiment  \
# 0    $GME       624          0.917613          0.874620          Negative
# 1   $TSLA      2376          0.903769          0.920804          Negative
# 2   $TWTR      2222          0.906162          0.902414          Negative
# 3    $AMC      3100          0.887694          0.885642          Negative
# 4    $SPY      4866          0.904432          0.918925          Negative
# 5   $HMHC        31          0.951600          0.928500          Negative
# 6   $DWAC       237          0.930353          0.916121          Negative
# 7    $AMD       743          0.942752          0.872440          Negative
# 8    $SST       383          0.929826          0.890256          Negative
# 9   $AAPL       671          0.931726          0.899890          Negative
# 10  $AMZN       461          0.936724          0.915718          Negative
# 11  $NVDA       481          0.933915          0.881431          Negative
# 12  $TLRY      1454          0.912634          0.913980          Positive
# 13  $NFLX        99          0.905240          0.898533          Negative
# 14   $QQQ       993          0.917019          0.909373          Negative
# 15  $PLTR       214          0.916360          0.920935          Positive
# 16    $FB       367          0.913546          0.903000          Negative
# 17  $BABA       269          0.926000          0.917190          Negative
# 18   $VIX       206          0.890524          0.925806          Positive
# 19  $SOFI       349          0.899209          0.885892          Negative
# 20  $TEAM        16          0.999000          0.946625          Positive
# 21  $RBLX       116          0.932919          0.921929          Negative
# 22   $RSX        17          0.881000          0.999000          Negative
# 23  $WISH        58          0.889870          0.883000          Negative
#
#                                         Top 20 Tweets  \
# 0   [gme flow putcall ratio  call premium million ...
# 1   [fortunate timing for tesla opening two ev fac...
# 2   [musk admits his twitter investment isnt passi...
# 3   [hey charlesyou recommended the weekly amc put...
# 4   [when spy gets short term oversold amp comes i...
# 5   [amusing to see rwallstreetbets going after th...
# 6   [dwac flow putcall ratio  call premium million...
# 7   [amd inbound for another retest of the  price ...
# 8   [sst  calls purchased last week returned  toda...
# 9   [aapl has surpassed million option contracts t...
# 10  [scoop the sec is investigating how amazon dis...
# 11  [nvda is up nearly  in the last years, bryan m...
# 12  [today  the worlds leading hemp brand and pion...
# 13  [excercise showing how discount rates impact v...
# 14  [qqq follow up, the failure last week of megac...
# 15  [pltr clientspartners update, this is a really...
# 16  [fb is considering using a virtual currency fo...
# 17  [baba flow putcall ratio  call premium million...
# 18  [you dont pile into stocks when the vix hits i...
# 19  [today was a huge win for the grassroots organ...
# 20  [you wished for it and we made it introducing ...
# 21  [according to  currently offers the highest pa...
# 22  [i made a live chart for anyone holding rsx to...
# 23  [this is another i get asked a lot about  wish...
#
#                                     20 Quality Tweets
# 0   [lol you think people are gonna sell amc while...
# 1   [tsla crashing, tsla cnbc faked us by making i...
# 2   [twtr mania if you think there is a takeover i...
# 3   [amc oops blew your load to early huh ken, amc...
# 4   [spy watching it test avwap  lower range of th...
# 5   [houghton mifflin harcourt company traded m sh...
# 6   [dwac s delayed issued press release on april ...
# 7   [amd like it here for a long  just need a boun...
# 8   [sst with da bounce, sst that is all, join our...
# 9   [crazy bc stocks have already fallen  or more ...
# 10  [amzn big hit coming from rivian fuel costs n ...
# 11  [nvda  ill sleep well holding and adding to my...
# 12  [everything red again tlry making moves today,...
# 13  [nflx for now just trading between this range ...
# 14  [qqq puts paying good job bears, qqq  c overni...
# 15  [pltr what the fucking fuck, pltr net dollar e...
# 16  [fb easy  in  months, added to my fb losing po...
# 17  [baba bagger here gt want more bangers, id go ...
# 18  [remember its been so bullish that the vix ros...
# 19  [man sofi really tried at  this week and last ...
# 20  [atlassian corporation plc  class a  team  pri...
# 21  [rblx another winning alert based on our custo...
# 22  [all i heard was rsx c, what does this mean fo...
# 23  [wish, disagree with you eric quiet period is ...

# %%
data = pd.read_csv("/work/Modeling/Outputs/twitter 04-02-2022.csv")

# %%
data['Top 20 Tweets']
# Out:
# 0     ['about to drop this  gme pokey editions stay ...
# 1     ['my wife is my guest to the cyber rodeo and i...
# 2     ['twtr got the break and retest but left us wi...
# 3     ['this is not accurate naked shorting abuses o...
# 4     ['spy resistance turned support turned resista...
# 5     ['hmhc open interest increases  on the week to...
# 6     ['donald trumps social media app was supposed ...
# 7     ['amd head and shoulders forming on the weekly...
# 8     ['im just saying it seems like theres some sen...
# 9     ['the market can be confusing but following un...
# 10    ['amzn super strong in aprilpay no mind to sep...
# 11    ['via heat map of how mega cap stocks b market...
# 12    ['and now a thread on stupidity see whiny twee...
# 13    ['netflix bought m carbon credits in this cut ...
# 14    ['coach i need to see another qqq pump commerc...
# 15    ['i took the time to normalize pltr quarterly ...
# 16    ['fb longterm trendline holds as support with ...
# 17    ['the market has a way of making you doubt you...
# 18    ['are you an vix chad as we are moving closer ...
# 19    ['its  you wake up and check twitter and see p...
# 20    ['team'\n 'get in early on solid and upcoming ...
# 21    ['rblx roblox launched on mobile years agoit g...
# 22    ['ur ukraine deputy defense min whole kyiv reg...
# 23    ['you could just invest  in wish and youll rea...
# Name: Top 20 Tweets, dtype: object

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=643f0a0a-e649-4860-b73b-f3561d8b41c9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
